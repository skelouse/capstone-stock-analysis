# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import plotly

# %%
def get_symbol_frequency(df, sym, freq=None):
    perf_min = df.reset_index()['date'].min()
    perf_max = df.reset_index()['date'].max()
    
    if freq:
        weekly_cut = pd.date_range(perf_min, perf_max, freq=freq)
        q=df.query("sym == '%s'"%sym).reset_index().set_index('date', drop=True).reindex(weekly_cut)
    else:
        q=df.query("sym == '%s'"%sym).reset_index().set_index('date', drop=True)
    return q.dropna()

# %%
df_performance = pd.read_pickle('./data/norm.pkl')
df_penny_performance = pd.read_pickle('./data/penny.pkl')
df_perc = pd.read_pickle('./data/perc.pkl')
# Out:
# For convinent loading 'from mlframe import MLFrame

# %%
get_symbol_frequency(df_performance, 'AAPL', freq=None).head()
# Out:
#              sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date
# 2019-08-09  AAPL    259034.0    94880.0           18117      0.77
# 2019-08-12  AAPL    259034.0    94880.0               0      0.77
# 2019-08-13  AAPL    259034.0    94880.0               0      0.77
# 2019-08-14  AAPL    259034.0    94880.0               0      0.77
# 2019-08-15  AAPL    259034.0    94880.0               0      0.77
#
#             DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date
# 2019-08-09        1.51403      9.55691       3.65644     9.353597e+11
# 2019-08-12        1.53241      9.44229       3.61259     9.243031e+11
# 2019-08-13        1.53631      9.41833       3.60342     9.219921e+11
# 2019-08-14        1.47390      9.81718       3.75602     9.604636e+11
# 2019-08-15        1.51911      9.52497       3.64422     9.322783e+11
#
#             PriceToCashFlow  ...  industry_Water Utilities  \
# date                         ...
# ...

# %%
import plotly.express as px

fig = px.line(get_symbol_frequency(df_performance, 'AAPL', freq=None).reset_index(), x='date', y='price')
fig.show()
# Out:
# <div>                            <div id="2d47ee9e-7105-4b93-941c-44d77fc8b28c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d47ee9e-7105-4b93-941c-44d77fc8b28c")) {                    Plotly.newPlot(                        "2d47ee9e-7105-4b93-941c-44d77fc8b28c",                        [{"hovertemplate": "date=%{x}<br>price=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2019-08-09T00:00:00", "2019-08-12T00:00:00", "2019-08-13T00:00:00", "2019-08-14T00:00:00", "2019-08-15T00:00:00", "2019-08-16T00:00:00", "2019-08-19T00:00:00", "2019-08-20T00:00:00", "2019-08-21T00:00:00", "2019-08-22T00:00:00", "2019-08-23T00:0
# ...
