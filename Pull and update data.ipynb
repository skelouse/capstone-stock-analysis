# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Style" data-toc-modified-id="Style-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Style</a></span></li><li><span><a href="#Imports-and-data" data-toc-modified-id="Imports-and-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Imports and data</a></span></li><li><span><a href="#Load-from-SQL" data-toc-modified-id="Load-from-SQL-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Load from SQL</a></span></li><li><span><a href="#Load-old-data-from-pickles" data-toc-modified-id="Load-old-data-from-pickles-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Load old data from pickles</a></span></li></ul></li><li><span><a href="#Test" data-toc-modified-id="Test-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Test</a></span></li><li><span><a href="#Prices" data-toc-modified-id="Prices-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prices</a></span><ul class="toc-item"><li><span><a href="#Clean" data-toc-modified-id="Clean-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Clean</a></span></li><li><span><a href="#Create-new-index,-and-diff" data-toc-modified-id="Create-new-index,-and-diff-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create new index, and diff</a></span></li><li><span><a href="#Reindex-Price" data-toc-modified-id="Reindex-Price-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Reindex Price</a></span></li><li><span><a href="#Post-to-SQL" data-toc-modified-id="Post-to-SQL-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Post to SQL</a></span></li><li><span><a href="#To-pickle" data-toc-modified-id="To-pickle-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>To pickle</a></span></li><li><span><a href="#Reset-prices" data-toc-modified-id="Reset-prices-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Reset prices</a></span></li></ul></li><li><span><a href="#Check-for-new-splits" data-toc-modified-id="Check-for-new-splits-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Check for new splits</a></span></li><li><span><a href="#Performance" data-toc-modified-id="Performance-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Performance</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Sort-old-index-old" data-toc-modified-id="Sort-old-index-old-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Sort old index old</a></span></li><li><span><a href="#load-in-data" data-toc-modified-id="load-in-data-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>load in data</a></span><ul class="toc-item"><li><span><a href="#Loc-relevant-symbols" data-toc-modified-id="Loc-relevant-symbols-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Loc relevant symbols</a></span></li></ul></li><li><span><a href="#Pull-out-new-data" data-toc-modified-id="Pull-out-new-data-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Pull out new data</a></span></li><li><span><a href="#Fill-ExDividendDate-and-map" data-toc-modified-id="Fill-ExDividendDate-and-map-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Fill ExDividendDate and map</a></span></li><li><span><a href="#Find-and-clean-new-values" data-toc-modified-id="Find-and-clean-new-values-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Find and clean new values</a></span></li><li><span><a href="#To-numeric" data-toc-modified-id="To-numeric-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>To numeric</a></span></li><li><span><a href="#Add-last-real-day-to-df_performance-for-interpolating" data-toc-modified-id="Add-last-real-day-to-df_performance-for-interpolating-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Add last real day to df_performance for interpolating</a></span></li><li><span><a href="#Create-new" data-toc-modified-id="Create-new-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Create new</a></span><ul class="toc-item"><li><span><a href="#Sort-index" data-toc-modified-id="Sort-index-5.9.1"><span class="toc-item-num">5.9.1&nbsp;&nbsp;</span>Sort index</a></span></li><li><span><a href="#Interpolate-null-values-by-symbol" data-toc-modified-id="Interpolate-null-values-by-symbol-5.9.2"><span class="toc-item-num">5.9.2&nbsp;&nbsp;</span>Interpolate null values by symbol</a></span></li></ul></li><li><span><a href="#Create-new" data-toc-modified-id="Create-new-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Create new</a></span><ul class="toc-item"><li><span><a href="#Sort-index-on-all_new" data-toc-modified-id="Sort-index-on-all_new-5.10.1"><span class="toc-item-num">5.10.1&nbsp;&nbsp;</span>Sort index on all_new</a></span></li></ul></li><li><span><a href="#Add-prices-to-performance" data-toc-modified-id="Add-prices-to-performance-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Add prices to performance</a></span><ul class="toc-item"><li><span><a href="#Separate-out-penny-stocks" data-toc-modified-id="Separate-out-penny-stocks-5.11.1"><span class="toc-item-num">5.11.1&nbsp;&nbsp;</span>Separate out penny stocks</a></span><ul class="toc-item"><li><span><a href="#Get-penny-stock-symbols-to-stay-whole" data-toc-modified-id="Get-penny-stock-symbols-to-stay-whole-5.11.1.1"><span class="toc-item-num">5.11.1.1&nbsp;&nbsp;</span>Get penny stock symbols to stay whole</a></span></li></ul></li></ul></li><li><span><a href="#To-pickle" data-toc-modified-id="To-pickle-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>To pickle</a></span></li><li><span><a href="#Post-to-SQL" data-toc-modified-id="Post-to-SQL-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>Post to SQL</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Separate-out-penny-stocks" data-toc-modified-id="Separate-out-penny-stocks-5.13.0.1"><span class="toc-item-num">5.13.0.1&nbsp;&nbsp;</span>Separate out penny stocks</a></span></li><li><span><a href="#Performance" data-toc-modified-id="Performance-5.13.0.2"><span class="toc-item-num">5.13.0.2&nbsp;&nbsp;</span>Performance</a></span></li><li><span><a href="#Penny" data-toc-modified-id="Penny-5.13.0.3"><span class="toc-item-num">5.13.0.3&nbsp;&nbsp;</span>Penny</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Company" data-toc-modified-id="Company-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Company</a></span></li><li><span><a href="#Analyst" data-toc-modified-id="Analyst-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Analyst</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Loc-relevant-symbols" data-toc-modified-id="Loc-relevant-symbols-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Loc relevant symbols</a></span></li><li><span><a href="#Loc-relevant-date" data-toc-modified-id="Loc-relevant-date-7.0.2"><span class="toc-item-num">7.0.2&nbsp;&nbsp;</span>Loc relevant date</a></span></li><li><span><a href="#Sort-old-index" data-toc-modified-id="Sort-old-index-7.0.3"><span class="toc-item-num">7.0.3&nbsp;&nbsp;</span>Sort old index</a></span></li><li><span><a href="#Add-last-real-day-to-df_analyst-for-interpolating" data-toc-modified-id="Add-last-real-day-to-df_analyst-for-interpolating-7.0.4"><span class="toc-item-num">7.0.4&nbsp;&nbsp;</span>Add last real day to df_analyst for interpolating</a></span></li></ul></li><li><span><a href="#Create-new" data-toc-modified-id="Create-new-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Create new</a></span><ul class="toc-item"><li><span><a href="#Sort-index" data-toc-modified-id="Sort-index-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Sort index</a></span></li><li><span><a href="#Iterate-to-map-and-fillna" data-toc-modified-id="Iterate-to-map-and-fillna-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Iterate to map and fillna</a></span></li><li><span><a href="#Convert-string-to-float" data-toc-modified-id="Convert-string-to-float-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Convert string to float</a></span></li></ul></li><li><span><a href="#Add-to-sql-server" data-toc-modified-id="Add-to-sql-server-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Add to sql server</a></span></li><li><span><a href="#Pickle" data-toc-modified-id="Pickle-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Pickle</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Sort-by-date/sym" data-toc-modified-id="Sort-by-date/sym-7.3.0.1"><span class="toc-item-num">7.3.0.1&nbsp;&nbsp;</span>Sort by date/sym</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Combine-company,-analyst-and-performance" data-toc-modified-id="Combine-company,-analyst-and-performance-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Combine company, analyst and performance</a></span><ul class="toc-item"><li><span><a href="#Performance" data-toc-modified-id="Performance-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Performance</a></span></li><li><span><a href="#Penny" data-toc-modified-id="Penny-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Penny</a></span></li><li><span><a href="#Write-pickles" data-toc-modified-id="Write-pickles-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Write pickles</a></span></li></ul></li><li><span><a href="#Post-to-firebase" data-toc-modified-id="Post-to-firebase-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Post to firebase</a></span></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# > Can be sped up by only filling from the last date, rather than filling from the entire previous data. The to_be_added_x could simply be added onto the old before pickling
# >
# > **This is a similar process to the pull and clean data, although measures have been taken to speed it up such as:**
# > * Only adding in one day, vs resetting all of the data
# > * Only comparing new data to one previous day for interpolation.
# > * Using previous indexes, so price creation only loops through 2000+ symbols vs 8000+ before
# > * For firebase updating with sym/col/date = x  rather than attempting to upload a dictionary every 100 symbols before

# %% [markdown]
# ## Style

# %%
import warnings
import matplotlib as mpl
mpl.rcParams['axes.titlesize']='xx-large'
mpl.rcParams['xtick.labelsize'] = 13
mpl.rcParams['ytick.labelsize'] = 13
mpl.rcParams['axes.labelsize'] = 16

# Styling notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>.shadowbox {
#     width: 40em;
#     border: 1px solid #333;
#     box-shadow: 8px 8px 5px #444;
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, black, rgb(107, 88, 88));
#     color: rgba(243, 218, 74, 0.801);
#     line-height: 25px;
#     position: static;
# }
#
# h1 {
#     width: 38em;
#     border: 1.5px solid #333;
#     /*box-shadow: 8px 8px 5px #444;*/
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, #fff, rgb(147, 156, 160));
#     position: static;
# }
#
# h2 {
#     width: 37em;
#     border: 1px solid #333;
#     /*box-shadow: 8px 8px 5px #444;*/
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, #fff, rgb(147, 156, 160));
#     position: relative;
#     right: -13px;
# }
#
# h3 {
#     width: 36em;
#     border: 0.5px solid #333;
#     /*box-shadow: 8px 8px 5px #444;*/
#     padding: 8px 12px;
#     background-image: linear-gradient(180deg, #fff, rgb(147, 156, 160));
# ...

# %% [markdown]
# ## Imports and data

# %%
USE_GPU = True
IGNORE_WARN = True
SEED = 42

import os
import sys
import time
import datetime
import importlib
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Imports for reproducability
import numpy as np
np.random.seed(SEED)

import tensorflow as tf
tf.random.set_seed(SEED)

if 'mlframe' in sys.modules:
    importlib.reload(sys.modules['mlframe'])
    importlib.reload(sys.modules['db'])

from db import DataBase
from mlframe import MLFrame

# Ignore warnings
if IGNORE_WARN:
    warnings.filterwarnings('ignore')
# Out:
# For convinent loading 'from mlframe import MLFrame
# C:\Users\12147\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Load from SQL
# > This could be sped up by only selecting the new dates or dates not in stock_cleaned

# %%
db = DataBase('stock', 14333, 'localhost')
db.cur.execute(
"""
SHOW TABLES
""")
db_names = list(table[0] for table in db.cur.fetchall())
db.pull_names_as_dataframes(db_names)
db.conn.close()

# %% [markdown]
# ## Load old data from pickles

# %%
old_df_prices = pd.read_pickle("./data/prices.pkl")
old_df_performance = pd.read_pickle('./data/performance.pkl')
old_df_penny_performance = pd.read_pickle('./data/penny_performance.pkl')
old_df_analyst = pd.read_pickle('./data/analyst.pkl')
df_company = pd.read_pickle('./data/company.pkl')

# %% [markdown]
# # Test

# %%
original = pd.DataFrame({
    'date': [1, 2, 1, 2, 1, 2],
    'sym': ['A', 'A', 'B', 'B', 'C', 'C'],
    'price': [10, 20, 10, 20, 10, 20]
}).set_index('date', drop=True)

new = pd.DataFrame({
    'date': [1, 2, 3, 1, 2, 1, 2, 3],
    'sym': ['A', 'A', 'A', 'B', 'B', 'C', 'C', 'C'],
    'price': [10, 20, 30, 10, 20, 10, 20, 30]  
}).set_index('date', drop=True)

# %%
display(original, new)
# Out:
#      sym  price
# date
# 1      A     10
# 2      A     20
# 1      B     10
# 2      B     20
# 1      C     10
# 2      C     20
#      sym  price
# date
# 1      A     10
# 2      A     20
# 3      A     30
# 1      B     10
# 2      B     20
# 1      C     10
# 2      C     20
# 3      C     30

# %%
expected = pd.DataFrame({
    'date': [3, 3, 3],
    'sym': ['A', 'B', 'C'],
    'price': [30, np.NaN, 30]  
}).set_index('date', drop=True)
expected
# Out:
#      sym  price
# date
# 3      A 30.000
# 3      B    nan
# 3      C 30.000

# %%
symbols = original['sym'].unique()
idx = [1, 2, 3]
sym_dfs = []
for sym in symbols:
    _new = new.loc[new['sym'] == sym]
    new_sym = pd.DataFrame(_new, index=idx)
    new_sym['sym'] = new_sym['sym'].fillna(method='ffill')
    new_sym['price'] = new_sym['price'].interpolate('pchip')  # fill with predicted value here
    sym_dfs.append(new_sym)
all_new = pd.concat(sym_dfs)
all_new.loc[all_new.index==3]
# Out:
#   sym  price
# 3   A 30.000
# 3   B 30.000
# 3   C 30.000

# %% [markdown]
# # Prices

# %% [markdown]
# ## Clean

# %%
# Cleaning first blank row
df_prices = db.frames['prices'].copy(deep=True).drop(0)

# Resetting date index and dropping index
df_prices.set_index('date', inplace=True, drop=True)

print("Null values = \n", df_prices.isna().sum())
# Out:
# Null values =
#  sym      0
# price    0
# dtype: int64

# %% [markdown]
# ## Create new index, and diff
# > * `newest_date` is the most recent date added to the server
# > * `date_idx` is the old date index i.e data that doesn't need to be updated
# > * `new_idx` is the new date index
# > * `idx_diff` is the day(s) that are being added and one day of the previous

# %%
assert(False) # Incorporate drop index
drop_index = pd.to_datetime(['2019-12-09', '2020-06-23', '2020-06-24', '2020-06-25'])

# %%
newest_date = df_prices.index.max()
newest_date
# Out:
# datetime.date(2020, 12, 8)

# %%
date_idx = old_df_prices.reset_index().query("sym == 'AAPL'")['date'].values
date_idx[:5], date_idx[-5:]
# Out:
# (array(['2019-08-09T00:00:00.000000000', '2019-08-12T00:00:00.000000000',
#         '2019-08-13T00:00:00.000000000', '2019-08-14T00:00:00.000000000',
#         '2019-08-15T00:00:00.000000000'], dtype='datetime64[ns]'),
#  array(['2020-12-02T00:00:00.000000000', '2020-12-03T00:00:00.000000000',
#         '2020-12-04T00:00:00.000000000', '2020-12-07T00:00:00.000000000',
#         '2020-12-08T00:00:00.000000000'], dtype='datetime64[ns]'))

# %%
new_idx = pd.date_range(date_idx[0], newest_date, freq='B')
new_idx[:2], new_idx[-2:]
# Out:
# (DatetimeIndex(['2019-08-09', '2019-08-12'], dtype='datetime64[ns]', freq='B'),
#  DatetimeIndex(['2020-12-07', '2020-12-08'], dtype='datetime64[ns]', freq='B'))

# %%
idx_diff = pd.date_range(date_idx[-1], newest_date, freq='B')[1:]
idx_diff
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='B')

# %% [markdown]
# ## Reindex Price

# %% [markdown]
# ```python
# symbols = original['sym'].unique()
# idx = [1, 2, 3]
# sym_dfs = []
# for sym in symbols:
#     _og = original.loc[original['sym'] == sym]
#     _new = new.loc[new['sym'] == sym]
#     new_sym = pd.DataFrame(_new, index=idx)
#     new_sym['sym'] = new_sym['sym'].fillna(method='ffill')
#     new_sym['price'] = new_sym['price'].interpolate('pchip')  # fill with predicted value here
#     sym_dfs.append(new_sym)
# all_new = pd.concat(sym_dfs)
# all_new.loc[all_new.index==3]
# ```

# %%
old_df_performance = pd.concat([old_df_performance, old_df_penny_performance])

# %%
all_symbols = old_df_performance.reset_index()['sym'].unique()
len(all_symbols)
# Out:
# 2107

# %%
df_prices = df_prices.loc[df_prices['sym'].isin(all_symbols)]
df_new_prices = df_prices.copy()
df_new_prices.index = pd.to_datetime(df_new_prices.index)
df_new_prices = df_new_prices.loc[df_new_prices.index.isin(new_idx)]

# %%
symbols = all_symbols
idx = new_idx
sym_dfs = []
for sym in symbols:
    _new = df_new_prices.loc[df_new_prices['sym'] == sym]
    new_sym = pd.DataFrame(_new, index=idx)
    new_sym['sym'] = new_sym['sym'].fillna(method='ffill')
    new_sym['price'] = pd.to_numeric(new_sym['price']).interpolate('pchip')
    sym_dfs.append(new_sym)
all_new = pd.concat(sym_dfs)
to_be_added_prices = all_new.loc[all_new.index.isin(idx_diff)]

# %%
df_test = to_be_added_prices.reset_index().copy()
missing_idx = df_test[~((df_test['sym']).isin(df_new_prices['sym']))]

# %%
to_be_added_prices.isna().sum()
# Out:
# sym      0
# price    0
# dtype: int64

# %%
df_price = to_be_added_prices
to_be_added_prices.head()
# Out:
# Empty DataFrame
# Columns: [sym, price]
# Index: []

# %%
all_new.isna().sum()
# Out:
# sym      0
# price    0
# dtype: int64

# %% [markdown]
# ## Post to SQL

# %%
df_prices = to_be_added_prices.reset_index()
df_prices.columns = ['date', 'sym', 'price']
df_prices = df_prices.set_index(['sym', 'date'], drop=True)

# %%
# Open database cleaned
db_clean = DataBase('stock_cleaned', 14333, 'localhost')
db_clean.pull_names_as_dataframes(['prices'])
db_clean.frames['prices']

# Make list of queries to post to sql
query_list = []
for idx, row in df_prices.reset_index().iterrows():
    query_list.append(tuple(row.to_dict().values()))

# Execute query
db_clean.cur.executemany("""
INSERT INTO prices (sym, date, price)
VALUES (%s, %s, %s)""",
      query_list)

# Commit
db_clean.conn.commit()

# Close db
db_clean.conn.close()

# %%
old_df_performance
# Out:
#              date   sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# 0      2019-08-09     A    5019.000   2155.000           0.000     0.164
# 1      2019-08-12     A    5019.000   2155.000           0.000     0.164
# 2      2019-08-13     A    5019.000   2155.000           0.000     0.164
# 3      2019-08-14     A    5019.000   2155.000           0.000     0.164
# 4      2019-08-15     A    5090.000   1765.000           0.000     0.164
# ...           ...   ...         ...        ...             ...       ...
# 722394 2020-12-01  ZEST       6.093      1.664           0.000     0.000
# 722395 2020-12-02  ZEST       6.093      1.664           0.000     0.000
# 722396 2020-12-03  ZEST       6.093      1.664           0.000     0.000
# 722397 2020-12-04  ZEST       6.093      1.664           0.000     0.000
# 722398 2020-12-07  ZEST       6.093      1.664           0.000     0.000
#
#         DividendYield  PriceToBook  PriceToSales  EnterpriseValue  ...     PE  \
# ...

# %% [markdown]
# ## To pickle

# %%
all_new = all_new.reset_index()
all_new.columns = ['date', 'sym', 'price']

# %%
all_new = all_new.set_index('date', drop=True)

# %%
all_new.to_pickle("./data/prices.pkl")
(all_new != pd.read_pickle("./data/prices.pkl")).sum()
# Out:
# sym      0
# price    0
# dtype: int64

# %% [markdown]
# ## Reset prices

# %%
df_prices = pd.read_pickle("./data/prices.pkl")
df_prices = df_prices.reset_index().set_index(['date'])
df_prices.index = pd.to_datetime(df_prices.index)

# %%
df_prices['sym'].nunique()
# Out:
# 2107

# %% [markdown]
# # Check for new splits

# %%
df_splits = db.frames['splits']

# %%
idx_diff
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='B')

# %%
assert(df_splits['execute'].isin(idx_diff).sum() == 0)

# %% [markdown]
# # Performance
# > **Steps to take**
# > * Load in performance, and clean
# > * Match index to prices
# > * Try to interpolate null values by one day as we did with prices
# > * Fill null ExDividend dates with 1970-01-01 then encode days since then for numerical data
# > * Decide what columns to drop, and which stocks to drop if they are in a given column
# > * Apply splits
# > * Post to sql server  CHECKPOINT
# > * Drop penny stocks ~1/5 of data

# %% [markdown]
# ## Functions

# %%
def get_perc_not_null(df):
    """Returns the percentages of null in each column to the length of the df"""
    nulls = df.isna().sum()
    return pd.Series(1 - nulls/len(df)).sort_values() * 100

# %%
def check_quantity_stocks_null_in_columns(df, cols):
    """Query to find how many stocks have a null value in any of these columns
        loc the rows that have any nulls in the given columns
        reset the index to 0-x
        get 'sym' series
        get the number of unique values
        """
    return df.loc[df[cols].isna().transpose().any()].reset_index()['sym'].nunique()

# %%
def try_replace(x):
    """Quick fix to some of the data having '1,300' instead of a number"""
    try:
        x = x.replace(',', '')
        return x
    except Exception:
        return x

# %%
drop_cols = ['PEG', 'FwdEPS3to5Yr', 'DividendCoverage', 'TotalReturn10Yr',
             'EPSGrowth5Year', 'TotalReturn5Yr']

# %% [markdown]
# ## Sort old index old

# %%
old_df_performance = old_df_performance.set_index(['sym', 'date'], drop=True).sort_index().reset_index().set_index(['date'], drop=True)

# %%
old_df_performance
# Out:
#              sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date
# 2019-08-09     A    5019.000   2155.000           0.000     0.164
# 2019-08-12     A    5019.000   2155.000           0.000     0.164
# 2019-08-13     A    5019.000   2155.000           0.000     0.164
# 2019-08-14     A    5019.000   2155.000           0.000     0.164
# 2019-08-15     A    5090.000   1765.000           0.000     0.164
# ...          ...         ...        ...             ...       ...
# 2020-12-02  ZYXI      68.679     41.229           0.000     0.000
# 2020-12-03  ZYXI      68.679     41.229           0.000     0.000
# 2020-12-04  ZYXI      68.679     41.229           0.000     0.000
# 2020-12-07  ZYXI      68.679     41.229           0.000     0.000
# 2020-12-08  ZYXI      68.679     41.229           0.000     0.000
#
#             DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date
# 2019-08-09          0.944        4.298         4.402  21670704590.000
# ...

# %% [markdown]
# ## load in data

# %%
# Cleaning first two blank rows
df_performance = db.frames['performance'].copy(deep=True).drop([0, 1])

# Drop cols
df_performance.drop(drop_cols, inplace=True, axis=1)

# Remove Dates that are less than august 8th, as that is from a different collection method
df_performance = df_performance[df_performance['date'] > pd.to_datetime('2019-08-08')]

# Resetting date index and dropping index
df_performance.set_index('date', inplace=True, drop=True)

# Dropping null date values
df_performance = df_performance.loc[df_performance.index.notnull()]

# Replace -- with NaN
df_performance.replace(['', '--'], np.NaN, inplace=True)
df_performance.head()
# Out:
#            sym         MCAP RevenueTTM TotalCash ExDividendDate Dividend  \
# date
# 2019-08-09   A  22027.70459       5019      2155            NaN    0.164
# 2019-08-12   A  21758.26224       5019      2155            NaN    0.164
# 2019-08-13   A  21121.11033       5019      2155            NaN    0.164
# 2019-08-14   A  21441.27124       5019      2155            NaN    0.164
# 2019-08-15   A      20332.9       5090      1765            NaN    0.164
#
#            DividendYield PriceToBook PriceToSales EnterpriseValue  ...    PE  \
# date                                                               ...
# 2019-08-09       0.94402     4.29809      4.40182     21670704590  ...  19.8
# 2019-08-12       0.95571     4.24551      4.34797     21401262240  ...  19.2
# 2019-08-13       0.98454     4.12119      4.22065     20764110330  ...  19.5
# 2019-08-14       0.96984     4.18366      4.28463     21084271240  ...  18.9
# ...

# %% [markdown]
# ### Loc relevant symbols

# %%
df_performance = df_performance.loc[df_performance['sym'].isin(all_symbols)]

# %% [markdown]
# ## Pull out new data

# %%
df_performance.index = pd.to_datetime(df_performance.index)

# %%
df_performance = df_performance.loc[df_performance.index.isin(df_performance.iloc[-(len(idx_diff))::].index)]
df_performance
# Out:
#              sym         MCAP RevenueTTM TotalCash ExDividendDate Dividend  \
# date
# 2019-08-09     A  22027.70459       5019      2155            NaN    0.164
# 2019-08-12     A  21758.26224       5019      2155            NaN    0.164
# 2019-08-13     A  21121.11033       5019      2155            NaN    0.164
# 2019-08-14     A  21441.27124       5019      2155            NaN    0.164
# 2019-08-15     A      20332.9       5090      1765            NaN    0.164
# ...          ...          ...        ...       ...            ...      ...
# 2020-12-02  ZYXI    466.86528     68.679    41.229            NaN      NaN
# 2020-12-03  ZYXI    456.44418     68.679    41.229            NaN      NaN
# 2020-12-04  ZYXI    469.99161     68.679    41.229            NaN      NaN
# 2020-12-07  ZYXI    490.83381     68.679    41.229            NaN      NaN
# 2020-12-08  ZYXI     479.3706     68.679    41.229            NaN      NaN
#
# ...

# %% [markdown]
# ## Fill ExDividendDate and map

# %%
fill_date = pd.to_datetime('1970-01-01')
df_performance = df_performance.reset_index().set_index('date', drop=True)
df_performance['ExDividendDate'] = pd.to_datetime(df_performance['ExDividendDate'].fillna(fill_date))
print("Null dates:", df_performance['ExDividendDate'].isna().sum())
df_performance['ExDividendDate'] = \
    df_performance['ExDividendDate'].map(lambda x: (x - fill_date).days)
df_performance.head()
# Out:
# Null dates: 0
#            sym         MCAP RevenueTTM TotalCash  ExDividendDate Dividend  \
# date
# 2019-08-09   A  22027.70459       5019      2155               0    0.164
# 2019-08-12   A  21758.26224       5019      2155               0    0.164
# 2019-08-13   A  21121.11033       5019      2155               0    0.164
# 2019-08-14   A  21441.27124       5019      2155               0    0.164
# 2019-08-15   A      20332.9       5090      1765               0    0.164
#
#            DividendYield PriceToBook PriceToSales EnterpriseValue  ...    PE  \
# date                                                               ...
# 2019-08-09       0.94402     4.29809      4.40182     21670704590  ...  19.8
# 2019-08-12       0.95571     4.24551      4.34797     21401262240  ...  19.2
# 2019-08-13       0.98454     4.12119      4.22065     20764110330  ...  19.5
# 2019-08-14       0.96984     4.18366      4.28463     21084271240  ...  18.9
# ...

# %% [markdown]
# ## Find and clean new values

# %%
for col in df_performance.head().columns:
    df_performance[col] = df_performance[col].map(try_replace)

# %% [markdown]
# ## To numeric

# %%
for col in df_performance.columns:
    if col != 'sym':
        df_performance[col] = pd.to_numeric(df_performance[col])

# %% [markdown]
# ## Add last real day to df_performance for interpolating

# %%
old_df_performance = old_df_performance.loc[old_df_performance.index[-1] == (old_df_performance.index)]
old_df_performance
# Out:
#              sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date
# 2020-12-08     A    5339.000   1441.000       18631.000     0.194
# 2020-12-08   AAL   24622.000   8792.000           0.000     0.100
# 2020-12-08  AAMC       4.127     44.909           0.000     0.000
# 2020-12-08  AAME     187.705      9.959           0.000     0.020
# 2020-12-08   AAP    9853.804   1068.205       18613.000     0.250
# ...          ...         ...        ...             ...       ...
# 2020-12-08  ZIXI     210.990     23.662           0.000     0.000
# 2020-12-08  ZNGA    1763.250    755.431           0.000     0.000
# 2020-12-08   ZTS    6555.000   3654.000           0.000     0.200
# 2020-12-08  ZUMZ     987.869    316.173           0.000     0.000
# 2020-12-08  ZYXI      68.679     41.229           0.000     0.000
#
#             DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date
# 2020-12-08          0.678        7.184         6.605  35924400000.000
# ...

# %% [markdown]
# ## Create new

# %%
df_new_performance = pd.concat([old_df_performance, df_performance])

# %% [markdown]
# ### Sort index

# %%
df_new_performance = df_new_performance.reset_index().set_index(['sym', 'date'], drop=True).sort_index().reset_index().set_index(['date'], drop=True)
df_new_performance
# Out:
#              sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date
# 2019-08-09     A    5019.000   2155.000           0.000     0.164
# 2019-08-12     A    5019.000   2155.000           0.000     0.164
# 2019-08-13     A    5019.000   2155.000           0.000     0.164
# 2019-08-14     A    5019.000   2155.000           0.000     0.164
# 2019-08-15     A    5090.000   1765.000           0.000     0.164
# ...          ...         ...        ...             ...       ...
# 2020-12-03  ZYXI      68.679     41.229           0.000       nan
# 2020-12-04  ZYXI      68.679     41.229           0.000       nan
# 2020-12-07  ZYXI      68.679     41.229           0.000       nan
# 2020-12-08  ZYXI      68.679     41.229           0.000     0.000
# 2020-12-08  ZYXI      68.679     41.229           0.000       nan
#
#             DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date
# 2019-08-09          0.944        4.298         4.402  21670704590.000
# ...

# %% [markdown]
# ### Interpolate null values by symbol

# %%
# takes symbols and idx from when prices ran through this
symbols = all_symbols
idx = df_new_performance.iloc[-(len(idx_diff)+1)::].index
sym_dfs = []

# %% [markdown]
# ## Create new

# %%
df_new_performance.drop(['MCAP', 'SharesOutstanding'], inplace=True, axis=1)

# %%
# takes symbols and idx from when prices ran through this
symbols = all_symbols
idx = df_new_performance.iloc[-(len(idx_diff)+1)::].index
sym_dfs = []

sym_num = len(all_symbols)
times = np.array([])

def cust_interpolate_fill_na(sym):
    # Locing new, and one before for filling to speed up
    _new = df_new_performance.loc[df_new_performance['sym'] == sym]
    new_sym['sym'] = new_sym['sym'].fillna(method='ffill')
    new_sym = new_sym.interpolate()
    sym_dfs.append(new_sym)

for num, sym in enumerate(symbols):
    start = time.time()
    cust_interpolate_fill_na(sym)  # Timed function
    end = time.time()
    time_taken = end-start
    times = np.append(times, time_taken)
    print(f"{num+1}/{sym_num} in {time_taken: .2f}s for {sym} :: averaging {times.mean():.2f}s/sym...", end='\r')
    
all_new = pd.concat(sym_dfs)
to_be_added_performance = all_new.loc[all_new.index.isin(idx_diff)]
# Out:
#            sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date
# 2019-08-09   A    5019.000   2155.000           0.000     0.164
# 2019-08-12   A    5019.000   2155.000           0.000     0.164
# 2019-08-13   A    5019.000   2155.000           0.000     0.164
# 2019-08-14   A    5019.000   2155.000           0.000     0.164
# 2019-08-15   A    5090.000   1765.000           0.000     0.164
# ...         ..         ...        ...             ...       ...
# 2020-12-03   A    5339.000   1441.000       18631.000     0.194
# 2020-12-04   A    5339.000   1441.000       18631.000     0.194
# 2020-12-07   A    5339.000   1441.000       18631.000     0.194
# 2020-12-08   A    5339.000   1441.000       18631.000     0.194
# 2020-12-08   A    5339.000   1441.000       18631.000     0.194
#
#             DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date
# 2019-08-09          0.944        4.298         4.402  21670704590.000
# ...

# %%
assert(to_be_added_performance.isna().sum().sum() == 0)
assert(all_new.isna().sum().sum() == 0)

# %%
old_df_performance = pd.read_pickle('./data/performance.pkl')
old_df_penny_performance = pd.read_pickle('./data/penny_performance.pkl')
old_df_performance = pd.concat([old_df_performance, old_df_penny_performance])
old_df_performance = old_df_performance.set_index('date', drop=True)

# %%
all_new = pd.concat([old_df_performance, to_be_added_performance])
all_new.tail()

# %% [markdown]
# ### Sort index on all_new

# %%
all_new = all_new.reset_index().set_index(['sym', 'date'], drop=True).sort_index().reset_index().set_index(['date'], drop=True)
all_new.tail()

# %%
all_new.isna().sum().sum()

# %% [markdown]
# ## Add prices to performance

# %%
all_new.drop('price', axis=1, inplace=True)

# %%
all_new = all_new.merge(df_prices.reset_index(), on=['date', 'sym'])

# %%
all_new.head()

# %% [markdown]
# ### Separate out penny stocks

# %% [markdown]
# #### Get penny stock symbols to stay whole

# %%
db_clean = DataBase('stock_cleaned', 14333, 'localhost')
db_clean.pull_names_as_dataframes(['penny_performance', 'performance'])
penny_symbols = db_clean.frames['penny_performance']['sym'].unique()
db_clean.conn.close()

# %%
len(penny_symbols)

# %%
all_new_penny = all_new.loc[all_new['sym'].isin(penny_symbols)]

# %%
no_longer_penny = (all_new_penny.loc[all_new_penny['price'] > 1])['sym'].nunique()
print(no_longer_penny, "symbols are no longer less than a dollar")

# %%
all_new = all_new.drop(all_new_penny.index)

# %%
all_new_penny['sym'].nunique()

# %%
all_new['sym'].nunique()

# %%
assert((all_new['sym'].nunique() + all_new_penny['sym'].nunique()) == len(all_symbols))

# %%
len(all_symbols)

# %% [markdown]
# ## To pickle

# %%
all_new_penny.to_pickle('./data/penny_performance.pkl')
assert((all_new_penny != pd.read_pickle('./data/penny_performance.pkl')).sum().sum() == 0)

# %%
all_new.to_pickle('./data/performance.pkl')
assert((all_new != pd.read_pickle('./data/performance.pkl')).sum().sum() == 0)

# %% [markdown]
# ## Post to SQL

# %% [markdown]
# #### Separate out penny stocks

# %%
to_be_added_performance = to_be_added_performance.reset_index()

# %%
to_be_added_performance_penny = to_be_added_performance.loc[to_be_added_performance['sym'].isin(penny_symbols)]

# %%
# Make sure this works
to_be_added_performance = to_be_added_performance.drop(to_be_added_performance_penny.index)

# %% [markdown]
# #### Performance

# %%
db_clean = DataBase('stock_cleaned', 14333, 'localhost')
# Make query list
query_list = []
for idx, row in to_be_added_performance.iterrows():
    query_list.append(tuple(row.to_dict().values()))

# Execute
db_clean.cur.executemany("""
REPLACE INTO performance (date, sym, RevenueTTM, TotalCash, ExDividendDate,
                    Dividend, DividendYield, PriceToBook, PriceToSales,
                    EnterpriseValue, PriceToCashFlow, PE, ReturnonEquity,
                    FreeCashFlow, TotalDebtToEquity, PricePerformance52Weeks,
                    PricePerformanceYTD, TotalReturn1Yr, TotalReturn3Yr,
                    VolumeAvg90Day, price)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""",
      query_list)

# commit
db_clean.conn.commit()

# %% [markdown]
# #### Penny

# %%
# Make query list
query_list_penny = []
for idx, row in to_be_added_performance_penny.iterrows():
    query_list_penny.append(tuple(row.to_dict().values()))
    
db_clean.cur.executemany("""
REPLACE INTO penny_performance (date, sym, RevenueTTM, TotalCash, ExDividendDate,
                    Dividend, DividendYield, PriceToBook, PriceToSales,
                    EnterpriseValue, PriceToCashFlow, PE, ReturnonEquity,
                    FreeCashFlow, TotalDebtToEquity, PricePerformance52Weeks,
                    PricePerformanceYTD, TotalReturn1Yr, TotalReturn3Yr,
                    VolumeAvg90Day, price)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""",
      query_list_penny)

db_clean.conn.commit()

# %% [markdown]
# # Company

# %%
df_company = db.frames['company'].copy(deep=True)

# Resetting date index and dropping index
df_company.set_index('sym', inplace=True, drop=True)

df_company.drop('date', inplace=True, axis=1)

df_company.replace(['', '--'], np.NaN, inplace=True)
df_company.head()
# Out:
#                        company securityType                  sector  \
# sym
# A     Agilent Technologies Inc           CS             Health Care
# AA                  Alcoa Corp           CS               Materials
# AABA                Altaba Inc           CS  Consumer Discretionary
# AAC           AAC Holdings Inc           CS             Health Care
# AACG     ATA Creativity Global           DR  Consumer Discretionary
#
#                                 industry                         subIndustry  \
# sym
# A         Life Sciences Tools & Services      Life Sciences Tools & Services
# AA                       Metals & Mining                            Aluminum
# AABA  Internet & Direct Marketing Retail  Internet & Direct Marketing Retail
# AAC     Health Care Providers & Services              Health Care Facilities
# AACG       Diversified Consumer Services                  Education Services
#
#      Exchange DJIA NASDAQ100 SP500
# sym
# A        NYSE    0         0     1
# ...

# %%
df_company = df_company.fillna('unknown')

# %%
df_company = df_company[df_company.index.isin(all_symbols)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0b9131a12862> in <module>
# ----> 1 df_company = df_company[df_company.index.isin(all_symbols)]
#
# NameError: name 'all_symbols' is not defined

# %%
df_company.to_pickle('./data/company.pkl')

# %% [markdown]
# # Analyst

# %%
# Cleaning first two blank rows
df_analyst = db.frames['analyst'].copy(deep=True).drop([0, 1])

# Resetting date index and dropping index
df_analyst.set_index('date', inplace=True, drop=True)

# Dropping null date values
df_analyst = df_analyst.loc[df_analyst.index.notnull()]

df_analyst.replace(['', '--'], np.NaN, inplace=True)

df_analyst
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2019-06-04     A   NaN      NaN                1                  3     70
# 2019-06-08     A   NaN      NaN                1                  3     70
# 2019-06-17     A   NaN      9.4                1                  3     70
# 2019-06-19     A   NaN      9.4                1                  3     70
# 2019-06-20     A   NaN        7                1                  3     70
# ...          ...   ...      ...              ...                ...    ...
# 2020-12-02  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-03  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-04  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-07  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-08  ZYXI   NaN      0.4              NaN                  3     42
#
# ...

# %% [markdown]
# ### Loc relevant symbols

# %%
df_analyst = df_analyst.loc[df_analyst['sym'].isin(all_symbols)]

# %%
df_analyst['sym'].nunique()
# Out:
# 2107

# %% [markdown]
# ### Loc relevant date

# %%
df_analyst_new = df_analyst.loc[df_analyst.index.isin(df_analyst.iloc[-(len(idx_diff))::].index)]
df_analyst_new
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2020-12-08     A   NaN      7.5              NaN                  3     70
# 2020-12-08   AAL  Hold      1.5              NaN                  5     72
# 2020-12-08  AAMC   NaN      NaN              NaN                NaN     82
# 2020-12-08  AAME   NaN      NaN              NaN                  1    NaN
# 2020-12-08   AAP   Buy      7.1              NaN                  2     55
# ...          ...   ...      ...              ...                ...    ...
# 2020-12-08  ZIXI   NaN      7.7              NaN                  2     34
# 2020-12-08  ZNGA   NaN        2              NaN                  3     90
# 2020-12-08   ZTS   Buy        5              NaN                  2     56
# 2020-12-08  ZUMZ   NaN      6.3              NaN                  2     91
# 2020-12-08  ZYXI   NaN      0.4              NaN                  3     42
#
# ...

# %%
old_df_analyst
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2019-08-09     A   NaN      5.8                1                  3     78
# 2019-08-12     A   NaN      8.3                1                  3     78
# 2019-08-13     A   NaN      8.3                1                  3     73
# 2019-08-14     A   NaN      4.2                1                  3     73
# 2019-08-15     A   NaN      4.2                1                  3     73
# ...          ...   ...      ...              ...                ...    ...
# 2020-12-02  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-03  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-04  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-07  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-08  ZYXI   NaN      0.4              NaN                  3     42
#
# ...

# %% [markdown]
# ### Sort old index

# %%
old_df_analyst = old_df_analyst.reset_index().set_index(['sym', 'date'], drop=True).sort_index().reset_index().set_index(['date'], drop=True)

# %%
old_df_analyst
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2019-08-09     A   NaN      5.8                1                  3     78
# 2019-08-12     A   NaN      8.3                1                  3     78
# 2019-08-13     A   NaN      8.3                1                  3     73
# 2019-08-14     A   NaN      4.2                1                  3     73
# 2019-08-15     A   NaN      4.2                1                  3     73
# ...          ...   ...      ...              ...                ...    ...
# 2020-12-02  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-03  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-04  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-07  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-08  ZYXI   NaN      0.4              NaN                  3     42
#
# ...

# %% [markdown]
# ### Add last real day to df_analyst for interpolating

# %%
old_df_analyst = old_df_analyst.reset_index().set_index(['date'], drop=True)

# %%
old_df_analyst = old_df_analyst.loc[old_df_analyst.index[-1] == (old_df_analyst.index)]
old_df_analyst
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2020-05-27     A   NaN      6.7                1                  3     66
# 2020-05-27   AAL  Hold      0.6                3                  4      0
# 2020-05-27  AAMC   NaN      NaN                3                NaN     82
# 2020-05-27  AAME   NaN      NaN                2                  3    NaN
# 2020-05-27   AAP   Buy      1.6                3                  3     12
# ...          ...   ...      ...              ...                ...    ...
# 2020-05-27  ZIXI   NaN      8.4                1                  2     23
# 2020-05-27  ZNGA   NaN      8.5                1                  2    100
# 2020-05-27   ZTS   Buy      7.2                1                  3     64
# 2020-05-27  ZUMZ   NaN      5.3                2                  3     98
# 2020-05-27  ZYXI   NaN      8.7                2                  2     43
#
# ...

# %% [markdown]
# ## Create new

# %%
df_analyst_new.index = pd.to_datetime(df_analyst_new.index)
old_df_analyst.index = pd.to_datetime(old_df_analyst.index)

# %%
df_new_analyst = pd.concat([old_df_analyst, df_analyst_new])

# %%
df_new_analyst
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2019-08-09     A   NaN      5.8                1                  3     78
# 2019-08-12     A   NaN      8.3                1                  3     78
# 2019-08-13     A   NaN      8.3                1                  3     73
# 2019-08-14     A   NaN      4.2                1                  3     73
# 2019-08-15     A   NaN      4.2                1                  3     73
# ...          ...   ...      ...              ...                ...    ...
# 2020-12-02  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-03  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-04  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-07  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-08  ZYXI   NaN      0.4              NaN                  3     42
#
# ...

# %% [markdown]
# ### Sort index

# %%
df_new_analyst = df_new_analyst.reset_index().set_index(['sym', 'date'], drop=True).sort_index().reset_index().set_index(['date'], drop=True)
df_new_analyst
# Out:
#              sym Argus StarMine ColumbineCapital FordEquityResearch ISSEVA  \
# date
# 2019-08-09     A   NaN      5.8                1                  3     78
# 2019-08-12     A   NaN      8.3                1                  3     78
# 2019-08-13     A   NaN      8.3                1                  3     73
# 2019-08-14     A   NaN      4.2                1                  3     73
# 2019-08-15     A   NaN      4.2                1                  3     73
# ...          ...   ...      ...              ...                ...    ...
# 2020-12-02  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-03  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-04  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-07  ZYXI   NaN      0.4              NaN                  3     42
# 2020-12-08  ZYXI   NaN      0.4              NaN                  3     42
#
# ...

# %% [markdown]
# ### Iterate to map and fillna

# %%
analyst_mapping = {
    'Argus': {0:0, 'Buy':5, 'Hold':3, 'Sell':1,
              5:5, 3:3, 1:1},
    'TradingCentral': {'Buy':5, '1':1, '3':3, '5':5, 0:0, 'Sell':1,
                       1:1, 3:3, 5:5},
    'Jefferson': {'Buy':5, '1':1, '3':3, '5':5, 'Hold':3, 'Sell':1,
                  1:1, 3:3, 5:5},
    'McLeanCapital': {'Buy':5, '1':1, '3':3, '5':5, 'Neutral':3, 'Sell':1,
                      1:1, 3:3, 5:5},
    'NedDavis': {'NEUTRAL':3, 'BUY':5, 'SELL':1,
                 1:1, 3:3, 5:5},
    'Zacks': {'STRONG BUY':6, 'BUY':5, 'OUTPERFORM':5,
             'NEUTRAL':3, 'HOLD':3, 'SELL':2, 'UNDERPERFORM':2,
             'STRONG SELL':1, 'NONE':0,
             1:1, 2:2, 3:3, 5:5, 6:6, 0:0},
    'ThomsonReutersVerus': {'HOLD':3, 'SELL':1, 'BUY':5,
                            1:1, 3:3, 5:5}
}

# %%
assert(False) # Double check analyst, and the column names are whole
assert(False)  # make sure the index matches performance before and after

# %%
# takes symbols and idx from when prices ran through this
symbols = all_symbols
idx = df_new_analyst.iloc[-(len(idx_diff)+1)::].index
sym_dfs = []

sym_num = len(symbols)
times = np.array([])

def cust_interpolate_fill_na(sym):
    # Locing new, and one before for filling to speed up
    _new = df_new_analyst.loc[df_new_analyst['sym'] == sym]
    new_sym = pd.DataFrame(_new, index=idx)
    new_sym['sym'] = sym
    new_sym = new_sym.fillna(method='ffill').fillna(0)
    for col, mapping in analyst_mapping.items():
        new_sym[col] = new_sym[col].map(mapping)
    if new_sym.isna().sum().sum() > 0:
        new_sym = new_sym.fillna(0)
    sym_dfs.append(new_sym)

for num, sym in enumerate(symbols):
    start = time.time()
    cust_interpolate_fill_na(sym)  # Timed function
    end = time.time()
    time_taken = end-start
    times = np.append(times, time_taken)
    print(f"{num+1}/{sym_num} in {time_taken: .2f}s for {sym} :: averaging {times.mean():.2f}s/sym...", end='\r')
    
all_new = pd.concat(sym_dfs)
to_be_added_analyst = all_new.loc[all_new.index.isin(idx_diff)]
# Out:
# 2107/2107 in  0.04s for ZEST :: averaging 0.04s/sym....
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-6538416bbfe0> in <module>
#      29
#      30 all_new = pd.concat(sym_dfs)
# ---> 31 to_be_added_analyst = all_new.loc[all_new.index.isin(idx_diff)]
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\indexes\datetimelike.py in isin(self, values, level)
#     481         if not isinstance(values, type(self)):
#     482             try:
# --> 483                 values = type(self)(values)
#     484             except ValueError:
#     485                 return self.astype(object).isin(values)
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\indexes\datetimes.py in __new__(cls, data, freq, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name)
#     261         if is_scalar(data):
#     262             raise TypeError(
# ...

# %%
asset(False)# Check index

# %% [markdown]
# ### Convert string to float

# %%
for col in to_be_added_analyst.columns:
    if col != 'sym':
        to_be_added_analyst[col] = pd.to_numeric(to_be_added_analyst[col])
        all_new[col] = pd.to_numeric(all_new[col])

# %%
to_be_added_analyst['TradingCentral'].unique()
# Out:
# array([3, 1, 0, 5], dtype=int64)

# %% [markdown]
# ## Add to sql server

# %%
db_clean = DataBase('stock_cleaned', 14333, 'localhost')
db_clean.pull_names_as_dataframes(['analyst'])
db_clean.frames['analyst']
# Out:
# Empty DataFrame
# Columns: [sym, date, Argus, StarMine, ColumbineCapital, FordEquityResearch, ISSEVA, Jefferson, McLeanCapital, NedDavis, TradingCentral, Zacks, SPValuation, SPQuality, SPGrowthStability, SPFinancialHealth, ThomsonReutersVerus, ThomsonReutersIBES]
# Index: []

# %%
query_list = []
for idx, row in to_be_added_analyst.reset_index().iterrows():
    query_list.append(tuple(row.to_dict().values()))

db_clean = DataBase('stock_cleaned', 14333, 'localhost')
db_clean.cur.executemany("""
REPLACE INTO analyst (date, sym, Argus, StarMine, ColumbineCapital,
                         FordEquityResearch, ISSEVA, Jefferson, McLeanCapital,
                         NedDavis, TradingCentral, Zacks, SPValuation,
                         SPQuality, SPGrowthStability, SPFinancialHealth,
                         ThomsonReutersVerus, ThomsonReutersIBES)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""",
      query_list)
db_clean.conn.commit()
db_clean.conn.close()

# %% [markdown]
# ## Pickle

# %%
assert(False) # Make sure all_new is all of the symbols,  may need to merge with old
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-118-b3ae2d3579e5> in <module>
# ----> 1 assert(False) # Make sure all_new is all of the symbols,  may need to merge with old
#
# AssertionError:

# %%
old_df_analyst = pd.read_pickle('./data/analyst.pkl')

# %%
all_new = pd.concat([old_df_analyst, all_new]).drop_duplicates()

# %% [markdown]
# #### Sort by date/sym

# %%
all_new = all_new.reset_index().set_index(['sym', 'date'], drop=True).sort_index().reset_index().set_index(['date'], drop=True)
# Out:
#              sym  Argus  StarMine  ColumbineCapital  FordEquityResearch  \
# date
# 2019-08-09     A      0     0.000             0.000               0.000
# 2020-12-04     A      0     7.500             1.000               3.000
# 2020-12-07     A      0     7.500             1.000               3.000
# 2020-12-08     A      0     7.500             1.000               3.000
# 2019-08-09   AAL      0     0.000             0.000               0.000
# ...          ...    ...       ...               ...                 ...
# 2020-12-08  ZUMZ      5     6.300             2.000               2.000
# 2019-08-09  ZYXI      0     0.000             0.000               0.000
# 2020-12-04  ZYXI      5     0.400             2.000               3.000
# 2020-12-07  ZYXI      5     0.400             2.000               3.000
# 2020-12-08  ZYXI      5     0.400             2.000               3.000
#
#             ISSEVA  Jefferson  McLeanCapital  NedDavis  TradingCentral  Zacks  \
# date
# ...

# %%
all_new = to_be_added_analyst

# %%
all_new.to_pickle('./data/analyst.pkl')
assert((all_new != pd.read_pickle('./data/analyst.pkl')).sum().sum() == 0)

# %% [markdown]
# # Combine company, analyst and performance

# %%
df_prices = pd.read_pickle("./data/prices.pkl")
df_performance = pd.read_pickle('./data/performance.pkl')
df_penny_performance = pd.read_pickle('./data/penny_performance.pkl')
df_analyst = pd.read_pickle('./data/analyst.pkl')

# %%
df_company.drop('subIndustry', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-82a6eccdf055> in <module>
# ----> 1 df_company.drop('subIndustry', axis=1, inplace=True)
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
def combine_df(df, company, analyst):
    ohe_columns = list(company.columns)
    ohe_columns.remove('company')
    df = df.reset_index().set_index(['date', 'sym'], drop=True)
    analyst = analyst.reset_index().set_index(['date', 'sym'], drop=True)
    df_new = MLFrame(df.join(df_company).join(analyst))
    df_new.drop('company', inplace=True, axis=1)
    df_new = df_new.one_hot_encode(columns=ohe_columns)
    return df_new

# %% [markdown]
# ## Performance

# %%
df_performance_combined = combine_df(df_performance, df_company, df_analyst)
df_performance_combined.head()
# Out:
# Added categorical columns
# 3 -> Dividend
# 4 -> Exchange
# 5 -> securityType
# 10 -> sector
# 68 -> industry
#                 index  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date       sym
# 2019-08-09 A        0    5019.000   2155.000           0.000     0.164
# 2019-08-12 A        1    5019.000   2155.000           0.000     0.164
# 2019-08-13 A        2    5019.000   2155.000           0.000     0.164
# 2019-08-14 A        3    5019.000   2155.000           0.000     0.164
# 2019-08-15 A        4    5090.000   1765.000           0.000     0.164
#
#                 DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date       sym
# 2019-08-09 A            0.944        4.298         4.402  21670704590.000
# 2019-08-12 A            0.956        4.246         4.348  21401262240.000
# 2019-08-13 A            0.985        4.121         4.221  20764110330.000
# 2019-08-14 A            0.970        4.184         4.285  21084271240.000
# ...

# %% [markdown]
# ## Penny

# %%
df_penny_performance_combined = combine_df(df_penny_performance, df_company, df_analyst)
df_penny_performance_combined.head()
# Out:
# Added categorical columns
# 3 -> Dividend
# 3 -> securityType
# 3 -> Exchange
# 10 -> sector
# 47 -> industry
#                  index  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# date       sym
# 2019-08-09 ACFN   6536       5.205      1.078           0.000     0.000
# 2019-08-12 ACFN   6537       5.205      1.078           0.000     0.000
# 2019-08-13 ACFN   6538       5.205      1.078           0.000     0.000
# 2019-08-14 ACFN   6539       5.205      1.078           0.000     0.000
# 2019-08-15 ACFN   6540       5.205      1.078           0.000     0.000
#
#                  DividendYield  PriceToBook  PriceToSales  EnterpriseValue  \
# date       sym
# 2019-08-09 ACFN          0.000        0.000         1.746      8486470.000
# 2019-08-12 ACFN          0.000        0.000         1.526      7344130.600
# 2019-08-13 ACFN          0.000        0.000         1.135      5309200.000
# 2019-08-14 ACFN          0.000        0.000         1.553      7484521.600
# ...

# %% [markdown]
# ## Write pickles

# %%
df_performance_combined.to_pickle('./data/performance_combined.pkl')
df_penny_performance_combined.to_pickle('./data/performance_penny_combined.pkl')

# %% [markdown]
# # Post to firebase

# %% [markdown]
# ```python
# # Test
#
# aal = {}
# sym_df = df_performance.groupby('sym')
# aal = sym_df.get_group('AAL').drop('sym', axis=1).reset_index(drop=True).to_dict()
# aal['AAL/Argus/322'] = 7
# req = fb.refresh_all_data(aal)
# ```
#
# > As this tests works, if we want to update a date i.e adding 322 we will have to generate the url for each column/key

# %%
from db import FireBase
import json
import os

# %%
fb = FireBase()

# %%
to_be_added_performance
# Out:
#            date   sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# 0    2020-12-08     A    5339.000   1441.000       18631.000     0.194
# 1    2020-12-08   AAL   24622.000   8792.000           0.000     0.100
# 2    2020-12-08  AAMC       4.127     44.909           0.000     0.000
# 3    2020-12-08  AAME     187.705      9.959           0.000     0.020
# 4    2020-12-08   AAP    9853.804   1068.205       18613.000     0.250
# ...         ...   ...         ...        ...             ...       ...
# 1888 2020-12-08  ZIXI     210.990     23.662           0.000     0.000
# 1889 2020-12-08  ZNGA    1763.250    755.431           0.000     0.000
# 1890 2020-12-08   ZTS    6555.000   3654.000           0.000     0.200
# 1891 2020-12-08  ZUMZ     987.869    316.173           0.000     0.000
# 1892 2020-12-08  ZYXI      68.679     41.229           0.000     0.000
#
#       DividendYield  PriceToBook  PriceToSales  EnterpriseValue  ...      PE  \
# ...

# %%
to_be_added_performance_penny
# Out:
#            date    sym  RevenueTTM  TotalCash  ExDividendDate  Dividend  \
# 1893 2020-12-08   ACFN       5.723      1.966           0.000     0.000
# 1894 2020-12-08   ACRX       5.153     43.023           0.000     0.000
# 1895 2020-12-08   ADMT       3.224      1.575           0.000     0.000
# 1896 2020-12-08   AERO      61.037      3.830           0.000     0.000
# 1897 2020-12-08   AIRI      48.933      1.460           0.000     0.000
# ...         ...    ...         ...        ...             ...       ...
# 2102 2020-12-08   XELB      36.865      5.461           0.000     0.000
# 2103 2020-12-08    XPL       0.408      8.574           0.000     0.000
# 2104 2020-12-08  XTGRF       3.228      7.670           0.000     0.000
# 2105 2020-12-08   ZDGE       9.470      5.111           0.000     0.000
# 2106 2020-12-08   ZEST       6.093      1.664           0.000     0.000
#
#       DividendYield  PriceToBook  PriceToSales  EnterpriseValue  ...     PE  \
# ...

# %%
df_post = pd.concat([to_be_added_performance, to_be_added_performance_penny])

# %%
fb_index = fb.get_index()

# %%
date_range = fb_index['data']['date_range']
date_range
# Out:
# ['08-09-2019',
#  '08-12-2019',
#  '08-13-2019',
#  '08-14-2019',
#  '08-15-2019',
#  '08-16-2019',
#  '08-19-2019',
#  '08-20-2019',
#  '08-21-2019',
#  '08-22-2019',
#  '08-23-2019',
#  '08-26-2019',
#  '08-27-2019',
#  '08-28-2019',
#  '08-29-2019',
#  '08-30-2019',
#  '09-02-2019',
#  '09-03-2019',
#  '09-04-2019',
#  '09-05-2019',
#  '09-06-2019',
#  '09-09-2019',
#  '09-10-2019',
#  '09-11-2019',
#  '09-12-2019',
#  '09-13-2019',
#  '09-16-2019',
#  '09-17-2019',
#  '09-18-2019',
#  '09-19-2019',
#  '09-20-2019',
#  '09-23-2019',
#  '09-24-2019',
#  '09-25-2019',
#  '09-26-2019',
#  '09-27-2019',
#  '09-30-2019',
#  '10-01-2019',
#  '10-02-2019',
#  '10-03-2019',
#  '10-04-2019',
#  '10-07-2019',
#  '10-08-2019',
#  '10-09-2019',
#  '10-10-2019',
#  '10-11-2019',
#  '10-14-2019',
#  '10-15-2019',
#  '10-16-2019',
#  '10-17-2019',
#  '10-18-2019',
#  '10-21-2019',
#  '10-22-2019',
#  '10-23-2019',
#  '10-24-2019',
#  '10-25-2019',
#  '10-28-2019',
#  '10-29-2019',
# ...

# %%
df_post = df_post.set_index('date', drop=True)

# %%
new_dates = pd.Series(df_post.index.unique()).map(lambda x: x.strftime("%m-%d-%Y")).values

# %%
to_add = {}
for date in new_dates:
    to_add[len(date_range)] = date
    date_range.append(date)

# %%
to_add
# Out:
# {343: '12-08-2020'}

# %%
to_add.keys()
# Out:
# dict_keys([343])

# %%
all_symbols = df_post['sym'].unique()

for val, date in to_add.items():
    sym_df = df_post.loc[date].groupby('sym')

    post = {}
    for sym in all_symbols:
        sym_new = sym_df.get_group(sym).drop('sym', axis=1).reset_index(drop=True).to_dict()
        for key, value in sym_new.items():
             post[f"{sym}/{key}/{val}"] = value[0]
    req = fb.refresh_all_data(post)
    try:
        req['req']
    except KeyError:
        print("REQUEST ERROR")
        print(req['error'])

# %%
date_range = pd.Series(date_range).to_dict()
df_post.reset_index(drop=True, inplace=True)
column_index = list(df_post.columns)
column_index.remove('sym')
column_index = dict(zip(range(len(column_index)), column_index))
all_symbols = df_post['sym'].unique()
symbol_index = tuple(all_symbols)
index = {
    'column': column_index,
    'date_range': date_range,
    'stocks': symbol_index
}
req = fb.refresh_index(index)
